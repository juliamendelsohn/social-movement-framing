# %%
import pandas as pd
import seaborn as sns
import os
from matplotlib import pyplot as plt

# %%
train_settings = ['guns','immigration','lgbtq','leave_out_guns','leave_out_immigration','leave_out_lgbtq']
eval_settings = ['guns','immigration','lgbtq']

# %%
eval_dir = '/home/juliame/social-movements/annotated_data/roberta_preds/04-12-2023/movement_splits/eval'

# %%
dfs = []
for train_setting in train_settings:
    for eval_setting in eval_settings:
        eval_file = os.path.join(eval_dir,f'{train_setting}_train_{eval_setting}_eval.tsv')
        df = pd.read_csv(eval_file,sep='\t')
        df.columns=['task','precision','recall','f1-score','support']
        df['train_setting'] = train_setting
        df['eval_setting'] = eval_setting
        dfs.append(df)
df = pd.concat(dfs).reset_index()
df = df.drop(columns=['index'])

# %%
df_macro = df[(df['task']=='macro avg')][['train_setting','eval_setting','f1-score']]

# %%
df_guns = df[(df['train_setting']=='leave_out_guns') & (df['eval_setting']=='guns')]
df_immigration = df[(df['train_setting']=='leave_out_immigration') & (df['eval_setting']=='immigration')]
df_lgbtq = df[(df['train_setting']=='leave_out_lgbtq') & (df['eval_setting']=='lgbtq')]
df_sub = pd.concat([df_guns,df_immigration,df_lgbtq])

# %%
df_sub
# Out:
#                       task  precision    recall  f1-score  support  \
# 144        Task1:relevance   0.653333  0.954545  0.775726    154.0
# 145       Task2:stance-pro   0.514851  0.776119  0.619048     67.0
# 146   Task2:stance-neutral   0.762295  0.628378  0.688889    148.0
# 147      Task2:stance-anti   0.333333  0.142857  0.200000     35.0
# 148  Task2:stance-explicit   0.775510  0.666667  0.716981     57.0
# 149         Task3:identify   0.546154  0.898734  0.679426     79.0
# 150            Task3:blame   0.512195  0.807692  0.626866     52.0
# 151         Task4:solution   0.611111  0.500000  0.550000     44.0
# 152          Task4:tactics   0.000000  0.000000  0.000000     24.0
# 153       Task4:solidarity   0.500000  0.600000  0.545455      5.0
# 154          Task4:counter   0.000000  0.000000  0.000000     12.0
# 155     Task5:motivational   1.000000  0.416667  0.588235     36.0
# 156              micro avg   0.624840  0.684432  0.653280    713.0
# 157              macro avg   0.517399  0.532638  0.499219    713.0
# 158           weighted avg   0.615663  0.684432  0.624315    713.0
# 159            samples avg   0.593600  0.671114  0.603106    713.0
# 208        Task1:relevance   0.834746  0.980100  0.901602    201.0
# 209       Task2:stance-pro   0.480392  0.620253  0.541436     79.0
# 210   Task2:stance-neutral   0.663636  0.623932  0.643172    117.0
# 211      Task2:stance-anti   0.380952  0.148148  0.213333     54.0
# 212  Task2:stance-explicit   0.575000  0.298701  0.393162     77.0
# 213         Task3:identify   0.723881  0.702899  0.713235    138.0
# 214            Task3:blame   0.666667  0.377358  0.481928    106.0
# 215         Task4:solution   0.474576  0.571429  0.518519     49.0
# 216          Task4:tactics   0.571429  0.333333  0.421053     12.0
# 217       Task4:solidarity   0.000000  0.000000  0.000000      6.0
# 218          Task4:counter   0.000000  0.000000  0.000000      6.0
# 219     Task5:motivational   0.500000  0.350000  0.411765     20.0
# 220              micro avg   0.667513  0.608092  0.636419    865.0
# 221              macro avg   0.489273  0.417179  0.436600    865.0
# 222           weighted avg   0.646128  0.608092  0.611845    865.0
# 223            samples avg   0.680724  0.621381  0.620937    865.0
# 272        Task1:relevance   0.956044  0.721992  0.822695    241.0
# 273       Task2:stance-pro   0.761905  0.210526  0.329897    152.0
# 274   Task2:stance-neutral   0.368687  0.839080  0.512281     87.0
# 275      Task2:stance-anti   0.250000  0.090909  0.133333     11.0
# 276  Task2:stance-explicit   0.600000  0.061856  0.112150     97.0
# 277         Task3:identify   0.901961  0.407080  0.560976    113.0
# 278            Task3:blame   0.750000  0.187500  0.300000     48.0
# 279         Task4:solution   0.600000  0.200000  0.300000     15.0
# 280          Task4:tactics   0.000000  0.000000  0.000000      9.0
# 281       Task4:solidarity   0.000000  0.000000  0.000000     61.0
# 282          Task4:counter   0.000000  0.000000  0.000000      3.0
# 283     Task5:motivational   0.000000  0.000000  0.000000     27.0
# 284              micro avg   0.679842  0.398148  0.502190    864.0
# 285              macro avg   0.432383  0.226579  0.255944    864.0
# 286           weighted avg   0.678430  0.398148  0.448632    864.0
# 287            samples avg   0.625590  0.433781  0.490614    864.0
#
#              train_setting eval_setting
# 144         leave_out_guns         guns
# 145         leave_out_guns         guns
# 146         leave_out_guns         guns
# 147         leave_out_guns         guns
# 148         leave_out_guns         guns
# 149         leave_out_guns         guns
# 150         leave_out_guns         guns
# 151         leave_out_guns         guns
# 152         leave_out_guns         guns
# 153         leave_out_guns         guns
# 154         leave_out_guns         guns
# 155         leave_out_guns         guns
# 156         leave_out_guns         guns
# 157         leave_out_guns         guns
# 158         leave_out_guns         guns
# 159         leave_out_guns         guns
# 208  leave_out_immigration  immigration
# 209  leave_out_immigration  immigration
# 210  leave_out_immigration  immigration
# 211  leave_out_immigration  immigration
# 212  leave_out_immigration  immigration
# 213  leave_out_immigration  immigration
# 214  leave_out_immigration  immigration
# 215  leave_out_immigration  immigration
# 216  leave_out_immigration  immigration
# 217  leave_out_immigration  immigration
# 218  leave_out_immigration  immigration
# 219  leave_out_immigration  immigration
# 220  leave_out_immigration  immigration
# 221  leave_out_immigration  immigration
# 222  leave_out_immigration  immigration
# 223  leave_out_immigration  immigration
# 272        leave_out_lgbtq        lgbtq
# 273        leave_out_lgbtq        lgbtq
# 274        leave_out_lgbtq        lgbtq
# 275        leave_out_lgbtq        lgbtq
# 276        leave_out_lgbtq        lgbtq
# 277        leave_out_lgbtq        lgbtq
# 278        leave_out_lgbtq        lgbtq
# 279        leave_out_lgbtq        lgbtq
# 280        leave_out_lgbtq        lgbtq
# 281        leave_out_lgbtq        lgbtq
# 282        leave_out_lgbtq        lgbtq
# 283        leave_out_lgbtq        lgbtq
# 284        leave_out_lgbtq        lgbtq
# 285        leave_out_lgbtq        lgbtq
# 286        leave_out_lgbtq        lgbtq
# 287        leave_out_lgbtq        lgbtq

# %%
sns.heatmap(df_macro.pivot("train_setting","eval_setting","f1-score"),
           annot=True,cmap='Blues')
# Out:
# <AxesSubplot:xlabel='eval_setting', ylabel='train_setting'>

# %%
def autolabel(rects, fmt='.2f'):
    # attach some text labels
    for rect in rects:
        height = rect.get_height()
        rect.axes.annotate(f'{{:{fmt}}}'.format(height),
                           xy=(rect.get_x()+rect.get_width()/2., height),
                           xytext=(0, 3), textcoords='offset points',
                           ha='center', va='bottom')

# %%
sns.catplot(x='task',y='f1-score',data=df_sub,hue='eval_setting',kind='bar',aspect=2)
